# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
titanic_train = pd.read_csv("https://gist.githubusercontent.com/michhar/2dfd2de0d4f8727f873422c5d959fff5/raw/ff414a1bcfcba32481e4d4e8db578e55872a2ca1/titanic.csv",sep='\t')   
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
titanic_train.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
a=titanic_train.dtypes[titanic_train.dtypes=='object']

# %%
a
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
a=titanic_train.dtypes[titanic_train.dtypes=='object'].index

# %%
a
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
s=titanic_train.PassengerId.astype('object')
s
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 151    152
# 152    153
# 153    154
# 154    155
# 155    156
# Name: PassengerId, Length: 156, dtype: object

# %%
a
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 151    152
# 152    153
# 153    154
# 154    155
# 155    156
# Name: PassengerId, Length: 156, dtype: object

# %%
a
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
titanic_train[a]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 151                  Pears, Mrs. Thomas (Edith Wearne)  female
# 152                                   Meo, Mr. Alfonzo    male
# 153                    van Billiard, Mr. Austin Blyler    male
# 154                              Olsen, Mr. Ole Martin    male
# 155                        Williams, Mr. Charles Duane    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
titanic_train[a].describe()
# Out:
#                  Name   Sex  Ticket Cabin Embarked
# count             156   156     156    31      155
# unique            156     2     145    28        3
# top     Bing, Mr. Lee  male  237736  C123        S
# freq                1   100       2     2      110

# %%
titanic_train.Sex.value_counts()
# Out:
# male      100
# female     56
# Name: Sex, dtype: int64

# %%
titanic_train.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
required_column_list=['Ticket', 'Fare', 'Cabin', 'Embarked']
required_column_list
# Out:
# ['Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
titanic_train[required_column_list]
# Out:
#                Ticket     Fare Cabin Embarked
# 0           A/5 21171   7.2500   NaN        S
# 1            PC 17599  71.2833   C85        C
# 2    STON/O2. 3101282   7.9250   NaN        S
# 3              113803  53.1000  C123        S
# 4              373450   8.0500   NaN        S
# ..                ...      ...   ...      ...
# 151            113776  66.6000    C2        S
# 152        A.5. 11206   8.0500   NaN        S
# 153          A/5. 851  14.5000   NaN        S
# 154         Fa 265302   7.3125   NaN        S
# 155          PC 17597  61.3792   NaN        C
#
# [156 rows x 4 columns]

# %%
titanic_train[['Ticket', 'Fare', 'Cabin']]
# Out:
#                Ticket     Fare Cabin
# 0           A/5 21171   7.2500   NaN
# 1            PC 17599  71.2833   C85
# 2    STON/O2. 3101282   7.9250   NaN
# 3              113803  53.1000  C123
# 4              373450   8.0500   NaN
# ..                ...      ...   ...
# 151            113776  66.6000    C2
# 152        A.5. 11206   8.0500   NaN
# 153          A/5. 851  14.5000   NaN
# 154         Fa 265302   7.3125   NaN
# 155          PC 17597  61.3792   NaN
#
# [156 rows x 3 columns]

# %%
type(titanic_train[['Ticket', 'Fare', 'Cabin']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(titanic_train['Ticket'])
# Out:
# pandas.core.series.Series

# %%
titanic_train['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 151              113776
# 152          A.5. 11206
# 153            A/5. 851
# 154           Fa 265302
# 155            PC 17597
# Name: Ticket, Length: 156, dtype: object

# %%
type(titanic_train[['Ticket']])
# Out:
# pandas.core.frame.DataFrame

# %%
titanic_train[['Ticket']]
# Out:
#                Ticket
# 0           A/5 21171
# 1            PC 17599
# 2    STON/O2. 3101282
# 3              113803
# 4              373450
# ..                ...
# 151            113776
# 152        A.5. 11206
# 153          A/5. 851
# 154         Fa 265302
# 155          PC 17597
#
# [156 rows x 1 columns]

# %%
sorted(titanic_train['Name'])
# Out:
# ['Ahlin, Mrs. Johan (Johanna Persdotter Larsson)',
#  'Allen, Mr. William Henry',
#  'Andersson, Miss. Ellis Anna Maria',
#  'Andersson, Miss. Erna Alexandra',
#  'Andersson, Mr. Anders Johan',
#  'Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andreasson, Mr. Paul Edvin',
#  'Andrew, Mr. Edgardo Samuel',
#  'Arnold-Franchi, Mrs. Josef (Josefine Franchi)',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)',
#  'Attalah, Miss. Malake',
#  'Backstrom, Mrs. Karl Alfred (Maria Mathilda Gustafsson)',
#  'Barton, Mr. David John',
#  'Bateman, Rev. Robert James',
#  'Baxter, Mr. Quigg Edmond',
#  'Beesley, Mr. Lawrence',
#  'Bing, Mr. Lee',
#  'Bonnell, Miss. Elizabeth',
#  'Boulos, Mrs. Joseph (Sultana)',
#  'Braund, Mr. Owen Harris',
#  'Burke, Mr. Jeremiah',
#  'Byles, Rev. Thomas Roussel Davids',
#  'Caldwell, Master. Alden Gates',
#  'Cann, Mr. Ernest Charles',
#  'Carrau, Mr. Francisco M',
#  'Celotti, Mr. Francesco',
#  'Chaffee, Mr. Herbert Fuller',
# ...

# %%
sorted(titanic_train['Name'])[5:10:2]
# Out:
# ['Andersson, Mr. August Edvard ("Wennerstrom")',
#  'Andrew, Mr. Edgardo Samuel',
#  'Asplund, Mrs. Carl Oscar (Selma Augusta Emilia Johansson)']

# %%
sorted(titanic_train['Name'],reverse=True)[:50]
# Out:
# ['van Billiard, Mr. Austin Blyler',
#  'Zabour, Miss. Hileni',
#  'Woolner, Mr. Hugh',
#  'Williams, Mr. Charles Eugene',
#  'Williams, Mr. Charles Duane',
#  'White, Mr. Richard Frasar',
#  'White, Mr. Percival Wayland',
#  'Wheadon, Mr. Edward H',
#  'West, Miss. Constance Mirium',
#  'Weisz, Mrs. Leopold (Mathilde Francoise Pede)',
#  'Webber, Miss. Susan',
#  'Waelens, Mr. Achille',
#  'Vestrom, Miss. Hulda Amanda Adolfina',
#  'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#  'Vander Planke, Miss. Augusta Maria',
#  'Uruchurtu, Don. Manuel E',
#  'Turpin, Mrs. William John Robert (Dorothy Ann Wonnacott)',
#  'Turpin, Mr. William John Robert',
#  'Todoroff, Mr. Lalio',
#  'Stewart, Mr. Albert A',
#  'Staneff, Mr. Ivan',
#  'Spencer, Mrs. William Augustus (Marie Eugenie)',
#  'Sobey, Mr. Samuel James Hayden',
#  'Sloper, Mr. William Thompson',
#  'Slocovski, Mr. Selman Francis',
#  'Skoog, Master. Harald',
#  'Sirayanian, Mr. Orsen',
#  'Shorney, Mr. Charles Joseph',
# ...

# %%
titanic_train[['Name']].describe()
# Out:
#                  Name
# count             156
# unique            156
# top     Bing, Mr. Lee
# freq                1

# %%
titanic_train[['Ticket']][4:9]
# Out:
#    Ticket
# 4  373450
# 5  330877
# 6   17463
# 7  349909
# 8  347742

# %%
titanic_train[['Ticket']][:5]
# Out:
#              Ticket
# 0         A/5 21171
# 1          PC 17599
# 2  STON/O2. 3101282
# 3            113803
# 4            373450

# %%
titanic_train.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass           Name   Sex         Age  \
# count    156.000000  156.000000  156.000000            156   156  126.000000
# unique          NaN         NaN         NaN            156     2         NaN
# top             NaN         NaN         NaN  Bing, Mr. Lee  male         NaN
# freq            NaN         NaN         NaN              1   100         NaN
# mean      78.500000    0.346154    2.423077            NaN   NaN   28.141508
# std       45.177428    0.477275    0.795459            NaN   NaN   14.613880
# min        1.000000    0.000000    1.000000            NaN   NaN    0.830000
# 25%       39.750000    0.000000    2.000000            NaN   NaN   19.000000
# 50%       78.500000    0.000000    3.000000            NaN   NaN   26.000000
# 75%      117.250000    1.000000    3.000000            NaN   NaN   35.000000
# max      156.000000    1.000000    3.000000            NaN   NaN   71.000000
#
# ...

# %%
titanic_train['Hamid']='ssddff'

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.dtypes!='object'
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age             True
# SibSp           True
# Parch           True
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# Hamid          False
# dtype: bool

# %%
a=titanic_train.dtypes[titanic_train.dtypes!='object'].index
a
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
titanic_train[a]
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ..           ...       ...     ...   ...    ...    ...      ...
# 151          152         1       1  22.0      1      0  66.6000
# 152          153         0       3  55.5      0      0   8.0500
# 153          154         0       3  40.5      0      2  14.5000
# 154          155         0       3   NaN      0      0   7.3125
# 155          156         0       1  51.0      0      1  61.3792
#
# [156 rows x 7 columns]

# %%
titanic_train[a].describeribe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000

# %%
new_class=pd.Categorical(titanic_train['Pclass'])

# %%
type(new_class)
# Out:
# pandas.core.arrays.categorical.Categorical

# %%
new_class
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(['one','Two','Three','one','Two','Three'] ,categories=['one','Two','Three'],ordered=True)
# Out:
# ['one', 'Two', 'Three', 'one', 'Two', 'Three']
# Categories (3, object): ['one' < 'Two' < 'Three']

# %%
titanic_train['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 151    1
# 152    3
# 153    3
# 154    3
# 155    1
# Name: Pclass, Length: 156, dtype: int64

# %%
new_class=pd.Categorical(titanic_train['Pclass'])
new_class
# Out:
# [3, 1, 3, 1, 3, ..., 1, 3, 3, 3, 1]
# Length: 156
# Categories (3, int64): [1, 2, 3]

# %%
titanic_train.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_train.Pclass.value_counts()
# Out:
# 3    96
# 2    30
# 1    30
# Name: Pclass, dtype: int64

# %%
titanic_train['Cabin'].unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2'], dtype=object)

# %%
import numpy as np 
char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str

# %%
new_Cabin = [cabin[0] for cabin in char_cabin] # Take first letter

# %%
new_Cabin
# Out:
# ['n',
#  'C',
#  'n',
#  'C',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'G',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'A',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'C',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'F',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'E',
#  'n',
#  'n',
#  'n',
#  'A',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'D',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'C',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'n',
#  'B',
#  'n',
#  'n',
#  'n',
#  'n',
#  'E',
#  'D',
# ...

# %%
new_Cabin = pd.Categorical(new_Cabin)

# %%
new_Cabin
# Out:
# ['n', 'C', 'n', 'C', 'n', ..., 'C', 'n', 'n', 'n', 'n']
# Length: 156
# Categories (8, object): ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'n']

# %%
char_cabin = titanic_train["Cabin"].astype(str) # Convert data to str
new_Cabin = [cabin[0:2] for cabin in char_cabin] # Take first letter
new_Cabin = pd.Categorical(new_Cabin)
new_Cabin
# Out:
# ['na', 'C8', 'na', 'C1', 'na', ..., 'C2', 'na', 'na', 'na', 'na']
# Length: 156
# Categories (24, object): ['A5', 'A6', 'B2', 'B3', ..., 'F2', 'F3', 'G6', 'na']

# %%
titanic_train["Cabin"] = new_Cabin
titanic_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   Hamid
# 0      0         A/5 21171   7.2500    na        S  ssddff
# 1      0          PC 17599  71.2833    C8        C  ssddff
# 2      0  STON/O2. 3101282   7.9250    na        S  ssddff
# 3      0            113803  53.1000    C1        S  ssddff
# ...

# %%
[1,2,3,4].__len__()
# Out:
# 4

# %%
titanic_train.notnull()
# Out:
#      PassengerId  Survived  Pclass  Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True  True  True   True   True   True    True
# 1           True      True    True  True  True   True   True   True    True
# 2           True      True    True  True  True   True   True   True    True
# 3           True      True    True  True  True   True   True   True    True
# 4           True      True    True  True  True   True   True   True    True
# ..           ...       ...     ...   ...   ...    ...    ...    ...     ...
# 151         True      True    True  True  True   True   True   True    True
# 152         True      True    True  True  True   True   True   True    True
# 153         True      True    True  True  True   True   True   True    True
# 154         True      True    True  True  True  False   True   True    True
# 155         True      True    True  True  True   True   True   True    True
#
#      Fare  Cabin  Embarked  Hamid
# ...

# %%
titanic_train.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 151        False     False   False  False  False  False  False  False   False
# 152        False     False   False  False  False  False  False  False   False
# 153        False     False   False  False  False  False  False  False   False
# 154        False     False   False  False  False   True  False  False   False
# 155        False     False   False  False  False  False  False  False   False
#
# ...

# %%
titanic_train["Age"].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId     0
# Survived        0
# Pclass          0
# Name            0
# Sex             0
# Age            30
# SibSp           0
# Parch           0
# Ticket          0
# Fare            0
# Cabin           0
# Embarked        1
# Hamid           0
# dtype: int64

# %%
titanic_train.notnull().sum()
# Out:
# PassengerId    156
# Survived       156
# Pclass         156
# Name           156
# Sex            156
# Age            126
# SibSp          156
# Parch          156
# Ticket         156
# Fare           156
# Cabin          156
# Embarked       155
# Hamid          156
# dtype: int64

# %%
np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))
# Out:
# (array([27, 88], dtype=int64),)

# %%
titanic_train.drop([0])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.drop(['PassengerId'],axis=1)
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 151         1       1                  Pears, Mrs. Thomas (Edith Wearne)
# 152         0       3                                   Meo, Mr. Alfonzo
# 153         0       3                    van Billiard, Mr. Austin Blyler
# 154         0       3                              Olsen, Mr. Ole Martin
# 155         0       1                        Williams, Mr. Charles Duane
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# ...

# %%
titanic_train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 151          152         1       1
# 152          153         0       3
# 153          154         0       3
# 154          155         0       3
# 155          156         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_train.Age.isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 151    False
# 152    False
# 153    False
# 154     True
# 155    False
# Name: Age, Length: 156, dtype: bool

# %%
titanic_train['Age'][titanic_train.Age.isnull()]
# Out:
# 5     NaN
# 17    NaN
# 19    NaN
# 26    NaN
# 28    NaN
# 29    NaN
# 31    NaN
# 32    NaN
# 36    NaN
# 42    NaN
# 45    NaN
# 46    NaN
# 47    NaN
# 48    NaN
# 55    NaN
# 64    NaN
# 65    NaN
# 76    NaN
# 77    NaN
# 82    NaN
# 87    NaN
# 95    NaN
# 101   NaN
# 107   NaN
# 109   NaN
# 121   NaN
# 126   NaN
# 128   NaN
# 140   NaN
# 154   NaN
# Name: Age, dtype: float64

# %%
titanic_train.iloc[5,:]
# Out:
# PassengerId                   6
# Survived                      0
# Pclass                        3
# Name           Moran, Mr. James
# Sex                        male
# Age                         NaN
# SibSp                         0
# Parch                         0
# Ticket                   330877
# Fare                     8.4583
# Cabin                        na
# Embarked                      Q
# Hamid                    ssddff
# Name: 5, dtype: object

# %%
titanic_train.iloc[5:10,0:5].index
# Out:
# RangeIndex(start=5, stop=10, step=1)

# %%
x=titanic_train['Age'][titanic_train.Age.isnull()].index

# %%
titanic_train.iloc[x,:]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %%
titanic_train['Age'][titanic_train.Age.isnull()].index

# %%
missing = np.where(titanic_train["Age"].isnull() == True)
missing
# Out:
# (array([  5,  17,  19,  26,  28,  29,  31,  32,  36,  42,  45,  46,  47,
#          48,  55,  64,  65,  76,  77,  82,  87,  95, 101, 107, 109, 121,
#         126, 128, 140, 154], dtype=int64),)

# %%
np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))
# Out:
# (array([27, 88], dtype=int64),)

# %%
idx=np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))

# %%
titanic_train.iloc[idx]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare Cabin Embarked   Hamid
# 27  19.0      3      2  19950  263.0    C2        S  ssddff
# 88  23.0      3      2  19950  263.0    C2        S  ssddff

# %%
titanic_train.iloc[np.where(titanic_train["Fare"]==max(titanic_train["Fare"]))]
# Out:
#     PassengerId  Survived  Pclass                            Name     Sex  \
# 27           28         0       1  Fortune, Mr. Charles Alexander    male
# 88           89         1       1      Fortune, Miss. Mabel Helen  female
#
#      Age  SibSp  Parch Ticket   Fare Cabin Embarked   Hamid
# 27  19.0      3      2  19950  263.0    C2        S  ssddff
# 88  23.0      3      2  19950  263.0    C2        S  ssddff

# %%
titanic_train["Family"] = titanic_train["SibSp"] + titanic_train["Parch"]
titanic_train["Family"]
most_family = np.where(titanic_train["Family"] == max(titanic_train["Family"]))
most_family
# Out:
# (array([59, 71], dtype=int64),)

# %%
titanic_train.iloc[most_family]
# Out:
#     PassengerId  Survived  Pclass                                Name     Sex  \
# 59           60         0       3  Goodwin, Master. William Frederick    male
# 71           72         0       3          Goodwin, Miss. Lillian Amy  female
#
#      Age  SibSp  Parch   Ticket  Fare Cabin Embarked   Hamid  Family
# 59  11.0      5      2  CA 2144  46.9    na        S  ssddff       7
# 71  16.0      5      2  CA 2144  46.9    na        S  ssddff       7

# %%
titanic_train.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Hamid', 'Family'],
#       dtype='object')

# %%
titanic_train.index=titanic_train.Name

# %%
titanic_train
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Pears, Mrs. Thomas (Edith Wearne)                           152         1
# Meo, Mr. Alfonzo                                            153         0
# van Billiard, Mr. Austin Blyler                             154         0
# Olsen, Mr. Ole Martin                                       155         0
# Williams, Mr. Charles Duane                                 156         0
#
#                                                     Pclass  \
# Name
# ...

# %%
titanic_train.loc[['Williams, Mr. Charles Duane'],titanic_train.columns]
# Out:
#                              PassengerId  Survived  Pclass  \
# Name
# Williams, Mr. Charles Duane          156         0       1
#
#                                                     Name   Sex   Age  SibSp  \
# Name
# Williams, Mr. Charles Duane  Williams, Mr. Charles Duane  male  51.0      0
#
#                              Parch    Ticket     Fare Cabin Embarked   Hamid  \
# Name
# Williams, Mr. Charles Duane      1  PC 17597  61.3792    na        C  ssddff
#
#                              Family
# Name
# Williams, Mr. Charles Duane       1
