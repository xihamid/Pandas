# %%
import pandas as pd

# %%
df=pd.read_csv("players_daya.csv")

# %%
df
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS    MP   FG  ...  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3  ...
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9  ...
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2  ...
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  ...
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1  ...
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7  ...
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  ...
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0  ...
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8  ...
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  ...
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  ...
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  ...
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  ...
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  ...
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  ...
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  ...
#
#       FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0   0.700  2.2  4.3  6.5  0.3  0.3  2.0  1.0  3.2   7.8
# 1   0.825  2.8  4.5  7.3  0.2  0.2  3.1  1.2  3.8   9.8
# 2   0.722  2.4  3.4  5.8  0.6  0.6  3.0  0.6  2.9   9.8
# 3   0.792  3.5  4.8  8.4  0.7  0.0  3.0  0.6  3.5  12.8
# 4   0.765  1.8  5.0  6.8  0.7  0.6  2.5  1.2  3.2  12.1
# 5   0.750  1.3  5.0  6.3  0.6  0.8  1.3  0.5  2.8  12.0
# 6   0.846  0.9  5.6  6.5  1.4  0.4  1.7  1.1  3.7  14.3
# 7   0.818  1.3  4.6  5.9  1.1  0.1  1.3  1.6  2.1   8.7
# 8   0.762  1.5  4.5  6.0  0.9  0.5  1.0  1.0  3.3   9.4
# 9   1.000  1.5  6.2  7.7  1.2  0.2  1.3  1.1  2.5  14.8
# 10  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.792  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  0.768  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 14  0.824  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
# 15  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
#
# [16 rows x 31 columns]

# %%
form_file=df

# %%
form_file.to_pickle('mypicke')

# %%
pwd()
# Out:
# 'C:\\Users\\Hamid\\Data Science\\(Pandas)'

# %%
form_file.to_csv('plysers_new.csv',index=False)

# %%
df=pd.read_csv('plysers_new.csv')

# %%
df
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS    MP   FG  ...  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3  ...
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9  ...
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2  ...
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  ...
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1  ...
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7  ...
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  ...
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0  ...
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8  ...
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  ...
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  ...
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  ...
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  ...
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  ...
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  ...
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  ...
#
#       FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0   0.700  2.2  4.3  6.5  0.3  0.3  2.0  1.0  3.2   7.8
# 1   0.825  2.8  4.5  7.3  0.2  0.2  3.1  1.2  3.8   9.8
# 2   0.722  2.4  3.4  5.8  0.6  0.6  3.0  0.6  2.9   9.8
# 3   0.792  3.5  4.8  8.4  0.7  0.0  3.0  0.6  3.5  12.8
# 4   0.765  1.8  5.0  6.8  0.7  0.6  2.5  1.2  3.2  12.1
# 5   0.750  1.3  5.0  6.3  0.6  0.8  1.3  0.5  2.8  12.0
# 6   0.846  0.9  5.6  6.5  1.4  0.4  1.7  1.1  3.7  14.3
# 7   0.818  1.3  4.6  5.9  1.1  0.1  1.3  1.6  2.1   8.7
# 8   0.762  1.5  4.5  6.0  0.9  0.5  1.0  1.0  3.3   9.4
# 9   1.000  1.5  6.2  7.7  1.2  0.2  1.3  1.1  2.5  14.8
# 10  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.792  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  0.768  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 14  0.824  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
# 15  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
#
# [16 rows x 31 columns]

# %%
h5_data=pd.HDFStore("'test.h5'")

# %%
h5_data['obj1']=df
# Out:
# C:\Users\Hamid\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3418: PerformanceWarning:
# your performance may suffer as PyTables will pickle object types that it cannot
# map directly to c-types [inferred_type->mixed,key->block2_values] [items->Index(['Season', 'Team', 'Lg', 'Pos'], dtype='object')]
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
h5_data['obj1']
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS    MP   FG  ...  \
# 0            0    2009-10  20.0  OKC  NBA   PF    6.0    0.0  25.5  3.3  ...
# 1            1    2010-11  21.0  OKC  NBA   PF   17.0   17.0  28.8  3.9  ...
# 2            2    2011-12  22.0  OKC  NBA   PF   20.0   20.0  28.5  4.2  ...
# 3            3    2012-13  23.0  OKC  NBA   PF   11.0   11.0  33.3  5.4  ...
# 4            4    2013-14  24.0  OKC  NBA   PF   17.0   17.0  34.2  5.1  ...
# 5            5    2015-16  26.0  OKC  NBA   PF   18.0   18.0  33.4  4.7  ...
# 6            6    2016-17  27.0  TOR  NBA   PF   10.0   10.0  30.7  6.0  ...
# 7            7    2017-18  28.0  TOR  NBA   PF   10.0    9.0  26.0  3.0  ...
# 8            8    2018-19  29.0  TOR  NBA    C   24.0    0.0  20.8  3.8  ...
# 9            9    2019-20  30.0  TOR  NBA    C   11.0    0.0  22.8  5.7  ...
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  ...
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  ...
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  ...
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  ...
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  ...
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  ...
#
#       FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0   0.700  2.2  4.3  6.5  0.3  0.3  2.0  1.0  3.2   7.8
# 1   0.825  2.8  4.5  7.3  0.2  0.2  3.1  1.2  3.8   9.8
# 2   0.722  2.4  3.4  5.8  0.6  0.6  3.0  0.6  2.9   9.8
# 3   0.792  3.5  4.8  8.4  0.7  0.0  3.0  0.6  3.5  12.8
# 4   0.765  1.8  5.0  6.8  0.7  0.6  2.5  1.2  3.2  12.1
# 5   0.750  1.3  5.0  6.3  0.6  0.8  1.3  0.5  2.8  12.0
# 6   0.846  0.9  5.6  6.5  1.4  0.4  1.7  1.1  3.7  14.3
# 7   0.818  1.3  4.6  5.9  1.1  0.1  1.3  1.6  2.1   8.7
# 8   0.762  1.5  4.5  6.0  0.9  0.5  1.0  1.0  3.3   9.4
# 9   1.000  1.5  6.2  7.7  1.2  0.2  1.3  1.1  2.5  14.8
# 10  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.792  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  0.768  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 14  0.824  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
# 15  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
#
# [16 rows x 31 columns]

# %%
h5_data.put('obj2',df,format='table')

# %%
h5_data.select('obj2',where=['index>=10 and index<=15'])
# Out:
#     Unnamed: 0     Season   Age Team   Lg  Pos      G     GS    MP   FG  ...  \
# 10          10    2020-21  31.0  LAC  NBA    C    2.0    0.0   9.0  1.5  ...
# 11          11     Career   NaN  NaN  NBA  NaN  146.0  102.0  28.1  4.5  ...
# 12          12        NaN   NaN  NaN  NaN  NaN    NaN    NaN   NaN  NaN  ...
# 13          13  6 seasons   NaN  OKC  NBA  NaN   89.0   83.0  31.0  4.5  ...
# 14          14  4 seasons   NaN  TOR  NBA  NaN   55.0   19.0  24.0  4.5  ...
# 15          15   1 season   NaN  LAC  NBA  NaN    2.0    0.0   9.0  1.5  ...
#
#       FT%  ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 10  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
# 11  0.792  1.9  4.7  6.5  0.7  0.4  2.0  1.0  3.1  11.0
# 12    NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   NaN
# 13  0.768  2.2  4.5  6.7  0.5  0.5  2.5  0.8  3.2  10.9
# 14  0.824  1.3  5.1  6.4  1.1  0.3  1.2  1.2  3.0  11.2
# 15  1.000  0.5  1.5  2.0  1.0  0.5  1.5  0.5  0.5   5.0
#
# [6 rows x 31 columns]

# %%
df=pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.dtypes=='object'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[ df.dtypes=='object']
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes=='object'].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df1=[df.dtypes[df.dtypes=='object'].index]

# %%
df1.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-784441b173b6> in <module>
# ----> 1 df1.describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes=='float'
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare            True
# Cabin          False
# Embarked       False
# dtype: bool

# %%
df[['Name','Fare']]
# Out:
#                                                   Name     Fare
# 0                              Braund, Mr. Owen Harris   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                               Heikkinen, Miss. Laina   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                             Allen, Mr. William Henry   8.0500
# ..                                                 ...      ...
# 886                              Montvila, Rev. Juozas  13.0000
# 887                       Graham, Miss. Margaret Edith  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"  23.4500
# 889                              Behr, Mr. Karl Howell  30.0000
# 890                                Dooley, Mr. Patrick   7.7500
#
# [891 rows x 2 columns]

# %%
df.dtypes[df.dtypes=='float64']
# Out:
# Age     float64
# Fare    float64
# dtype: object

# %%
type(df.dtypes[df.dtypes=='float64'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes=='float64'].index]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
df[["Age","Fare"]]
# Out:
#       Age     Fare
# 0    22.0   7.2500
# 1    38.0  71.2833
# 2    26.0   7.9250
# 3    35.0  53.1000
# 4    35.0   8.0500
# ..    ...      ...
# 886  27.0  13.0000
# 887  19.0  30.0000
# 888   NaN  23.4500
# 889  26.0  30.0000
# 890  32.0   7.7500
#
# [891 rows x 2 columns]

# %%
l=[4,5,6,7,8,9,10,11,55]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
df['Name'][5]
# Out:
# 'Moran, Mr. James'

# %%
df['Name'][5:10]
# Out:
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Name'][5:10:2]
# Out:
# 5                       Moran, Mr. James
# 7         Palsson, Master. Gosta Leonard
# 9    Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
df['Ticket'][5:16]
# Out:
# 5        330877
# 6         17463
# 7        349909
# 8        347742
# 9        237736
# 10      PP 9549
# 11       113783
# 12    A/5. 2151
# 13       347082
# 14       350406
# 15       248706
# Name: Ticket, dtype: object

# %%
df[['Ticket']][5:16]
# Out:
#        Ticket
# 5      330877
# 6       17463
# 7      349909
# 8      347742
# 9      237736
# 10    PP 9549
# 11     113783
# 12  A/5. 2151
# 13     347082
# 14     350406
# 15     248706

# %%
sorted(df['Ticket'][5:16])
# Out:
# ['113783',
#  '17463',
#  '237736',
#  '248706',
#  '330877',
#  '347082',
#  '347742',
#  '349909',
#  '350406',
#  'A/5. 2151',
#  'PP 9549']

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
for i in df.columns:
    print(df[i])
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: object
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64
# 0      1
# 1      1
# 2      0
# 3      1
# 4      0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 891, dtype: int64
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 886    0
# 887    0
# 888    2
# 889    0
# 890    0
# Name: Parch, Length: 891, dtype: int64
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object
# 0       7.2500
# 1      71.2833
# 2       7.9250
# 3      53.1000
# 4       8.0500
#         ...
# 886    13.0000
# 887    30.0000
# 888    23.4500
# 889    30.0000
# 890     7.7500
# Name: Fare, Length: 891, dtype: float64
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df['hamid']='mughal'

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   hamid  hamid1
# 0      0         A/5 21171   7.2500   NaN        S  mughal       1
# 1      0          PC 17599  71.2833   C85        C  mughal       2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  mughal       3

# %%
df['hamid1']=df['PassengerId']

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked   hamid  hamid1
# 0      0         A/5 21171   7.2500   NaN        S  mughal       1
# 1      0          PC 17599  71.2833   C85        C  mughal       2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  mughal       3

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   hamid  hamid1
# 0        0         A/5 21171   7.2500   NaN        S  mughal       1
# 1        0          PC 17599  71.2833   C85        C  mughal       2
# 2        0  STON/O2. 3101282   7.9250   NaN        S  mughal       3
# 3        0            113803  53.1000  C123        S  mughal       4
# 4        0            373450   8.0500   NaN        S  mughal       5
# ..     ...               ...      ...   ...      ...     ...     ...
# 886      0            211536  13.0000   NaN        S  mughal     887
# 887      0            112053  30.0000   B42        S  mughal     888
# 888      2        W./C. 6607  23.4500   NaN        S  mughal     889
# 889      0            111369  30.0000  C148        C  mughal     890
# 890      0            370376   7.7500   NaN        Q  mughal     891
#
# [891 rows x 14 columns]

# %%
df['Cabin']
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
pd.Categorical(df['Cabin'])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
pd.Categorical(df['Sex'])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
pd.Categorical(df['Pclass'])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df['Pclass'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Pclass, Length: 891, dtype: bool

# %%
df['Cabin'].isnull()
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df['Cabin'].isnull()==True
# Out:
# 0       True
# 1      False
# 2       True
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: Cabin, Length: 891, dtype: bool

# %%
df['Cabin'][df['Cabin'].isnull()==True]
# Out:
# 0      NaN
# 2      NaN
# 4      NaN
# 5      NaN
# 7      NaN
#       ...
# 884    NaN
# 885    NaN
# 886    NaN
# 888    NaN
# 890    NaN
# Name: Cabin, Length: 687, dtype: object

# %%
df['Cabin'][df['Cabin'].isnull()==False]
# Out:
# 1              C85
# 3             C123
# 6              E46
# 10              G6
# 11            C103
#           ...
# 871            D35
# 872    B51 B53 B55
# 879            C50
# 887            B42
# 889           C148
# Name: Cabin, Length: 204, dtype: object

# %%
ser=df['Cabin'][df['Cabin'].isnull()==False]

# %%
ser.index
# Out:
# Int64Index([  1,   3,   6,  10,  11,  21,  23,  27,  31,  52,
#             ...
#             849, 853, 857, 862, 867, 871, 872, 879, 887, 889],
#            dtype='int64', length=204)

# %% [markdown]
# # Rows Operations

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked   hamid  hamid1
# 1        0  PC 17599  71.2833          C85        C  mughal       2
# 3        0    113803  53.1000         C123        S  mughal       4
# 6        0     17463  51.8625          E46        S  mughal       7
# 10       1   PP 9549  16.7000           G6        S  mughal      11
# 11       0    113783  26.5500         C103        S  mughal      12
# ..     ...       ...      ...          ...      ...     ...     ...
# 871      1     11751  52.5542          D35        S  mughal     872
# 872      0       695   5.0000  B51 B53 B55        S  mughal     873
# 879      1     11767  83.1583          C50        C  mughal     880
# 887      0    112053  30.0000          B42        S  mughal     888
# 889      0    111369  30.0000         C148        C  mughal     890
#
# [204 rows x 14 columns]

# %%
df.iloc[[1,9,8,10]]
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 9            10         1       2
# 8             9         1       3
# 10           11         1       3
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 8   Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                    Sandstrom, Miss. Marguerite Rut  female   4.0      1
#
#     Parch    Ticket     Fare Cabin Embarked   hamid  hamid1
# 1       0  PC 17599  71.2833   C85        C  mughal       2
# 9       0    237736  30.0708   NaN        C  mughal      10
# 8       2    347742  11.1333   NaN        S  mughal       9
# 10      1   PP 9549  16.7000    G6        S  mughal      11

# %%
ser=df['Cabin'][df['Cabin'].isnull()==True]

# %%
ser.index
# Out:
# Int64Index([  0,   2,   4,   5,   7,   8,   9,  12,  13,  14,
#             ...
#             878, 880, 881, 882, 883, 884, 885, 886, 888, 890],
#            dtype='int64', length=687)

# %%
df.iloc[ser.index]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#       hamid  hamid1
# 0    mughal       1
# 2    mughal       3
# 4    mughal       5
# 5    mughal       6
# 7    mughal       8
# ..      ...     ...
# 884  mughal     885
# 885  mughal     886
# 886  mughal     887
# 888  mughal     889
# 890  mughal     891
#
# [687 rows x 14 columns]

# %%
len(ser.index)
# Out:
# 687

# %%
df['Fare']==max(df['Fare'])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df['Fare']==max(df['Fare'])]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
#
#       hamid  hamid1
# 258  mughal     259
# 679  mughal     680
# 737  mughal     738

# %%
df[df['Fare']==max(df['Fare'])]['Name']
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
df['new_col']=df['PassengerId']+df['Age']

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked   hamid  hamid1  new_col
# 0        0         A/5 21171   7.2500   NaN        S  mughal       1     23.0
# 1        0          PC 17599  71.2833   C85        C  mughal       2     40.0
# 2        0  STON/O2. 3101282   7.9250   NaN        S  mughal       3     29.0
# 3        0            113803  53.1000  C123        S  mughal       4     39.0
# 4        0            373450   8.0500   NaN        S  mughal       5     40.0
# ..     ...               ...      ...   ...      ...     ...     ...      ...
# 886      0            211536  13.0000   NaN        S  mughal     887    914.0
# 887      0            112053  30.0000   B42        S  mughal     888    907.0
# 888      2        W./C. 6607  23.4500   NaN        S  mughal     889      NaN
# 889      0            111369  30.0000  C148        C  mughal     890    916.0
# 890      0            370376   7.7500   NaN        Q  mughal     891    923.0
#
# [891 rows x 15 columns]
